# %% [markdown]
# <a href="https://colab.research.google.com/github/parshav42/learing/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %time
# # Authors: The scikit-learn developers
# # SPDX-License-Identifier: BSD-3-Clause

# import matplotlib.pyplot as plt
# import numpy as np
# from matplotlib.colors import ListedColormap

# from sklearn.datasets import make_circles, make_classification, make_moons
# from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
# from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
# from sklearn.gaussian_process import GaussianProcessClassifier
# from sklearn.gaussian_process.kernels import RBF
# from sklearn.inspection import DecisionBoundaryDisplay
# from sklearn.model_selection import train_test_split
# from sklearn.naive_bayes import GaussianNB
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.neural_network import MLPClassifier
# from sklearn.pipeline import make_pipeline
# from sklearn.preprocessing import StandardScaler
# from sklearn.svm import SVC
# from sklearn.tree import DecisionTreeClassifier

# names = [
#     "Nearest Neighbors",
#     "Linear SVM",
#     "RBF SVM",
#     "Gaussian Process",
#     "Decision Tree",
#     "Random Forest",
#     "Neural Net",
#     "AdaBoost",
#     "Naive Bayes",
#     "QDA",
# ]

# classifiers = [
#     KNeighborsClassifier(3),
#     SVC(kernel="linear", C=0.025, random_state=42),
#     SVC(gamma=2, C=1, random_state=42),
#     GaussianProcessClassifier(1.0 * RBF(1.0), random_state=42),
#     DecisionTreeClassifier(max_depth=5, random_state=42),
#     RandomForestClassifier(
#         max_depth=5, n_estimators=10, max_features=1, random_state=42
#     ),
#     MLPClassifier(alpha=1, max_iter=1000, random_state=42),
#     AdaBoostClassifier(random_state=42),
#     GaussianNB(),
#     QuadraticDiscriminantAnalysis(),
# ]

# X, y = make_classification(
#     n_features=2, n_redundant=0, n_informative=2, random_state=1, n_clusters_per_class=1
# )
# rng = np.random.RandomState(2)
# X += 2 * rng.uniform(size=X.shape)
# linearly_separable = (X, y)

# datasets = [
#     make_moons(noise=0.3, random_state=0),
#     make_circles(noise=0.2, factor=0.5, random_state=1),
#     linearly_separable,
# ]

# figure = plt.figure(figsize=(27, 9))
# i = 1
# # iterate over datasets
# for ds_cnt, ds in enumerate(datasets):
#     # preprocess dataset, split into training and test part
#     X, y = ds
#     X_train, X_test, y_train, y_test = train_test_split(
#         X, y, test_size=0.4, random_state=42
#     )

#     x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 0.5
#     y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 0.5

#     # just plot the dataset first
#     cm = plt.cm.RdBu
#     cm_bright = ListedColormap(["#FF0000", "#0000FF"])
#     ax = plt.subplot(len(datasets), len(classifiers) + 1, i)
#     if ds_cnt == 0:
#         ax.set_title("Input data")
#     # Plot the training points
#     ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright, edgecolors="k")
#     # Plot the testing points
#     ax.scatter(
#         X_test[:, 0], X_test[:, 1], c=y_test, cmap=cm_bright, alpha=0.6, edgecolors="k"
#     )
#     ax.set_xlim(x_min, x_max)
#     ax.set_ylim(y_min, y_max)
#     ax.set_xticks(())
#     ax.set_yticks(())
#     i += 1

#     # iterate over classifiers
#     for name, clf in zip(names, classifiers):
#         ax = plt.subplot(len(datasets), len(classifiers) + 1, i)

#         clf = make_pipeline(StandardScaler(), clf)
#         clf.fit(X_train, y_train)
#         score = clf.score(X_test, y_test)
#         DecisionBoundaryDisplay.from_estimator(
#             clf, X, cmap=cm, alpha=0.8, ax=ax, eps=0.5
#         )

#         # Plot the training points
#         ax.scatter(
#             X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright, edgecolors="k"
#         )
#         # Plot the testing points
#         ax.scatter(
#             X_test[:, 0],
#             X_test[:, 1],
#             c=y_test,
#             cmap=cm_bright,
#             edgecolors="k",
#             alpha=0.6,
#         )

#         ax.set_xlim(x_min, x_max)
#         ax.set_ylim(y_min, y_max)
#         ax.set_xticks(())
#         ax.set_yticks(())
#         if ds_cnt == 0:
#             ax.set_title(name)
#         ax.text(
#             x_max - 0.3,
#             y_min + 0.3,
#             ("%.2f" % score).lstrip("0"),
#             size=15,
#             horizontalalignment="right",
#         )
#         i += 1

# plt.tight_layout()
# plt.show()

# %%
import sklearn as sk
from seaborn import load_dataset as pk

from sklearn.datasets import load_iris ,fetch_covtype,load_wine
# Changed to load_iris
import pandas as pd

# p = load_iris()
s = pk('tips')
# p=load_wine() # Now p will be a dataset object

# data = p.data
# target = p.target


# Separate X and y
# Train/test split
# Train a Linear Regression model
# Make predictions
# Calculate MAE/MSE/R²
# Logistic Regression classification
# Confusion matrix
# Accuracy, precision, recall

# %%
c = pd.DataFrame(s)
c.head()

# %%
import seaborn as sn
#//Load the tips dataset and create a basic scatter plot using sns.scatterplot() to show total_bill vs tip.//
sn.scatterplot(c, x = 'total_bill',y ="tip")

# %%
# 2. Line Plot

# Create a line plot using the tips dataset to observe how a numerical value changes according to the index/order of the observations.

# Think: Which variable would make sense for the y-axis?

sn.lineplot(data=c,x='time',y='tip')

# %%
# 3. Histogram

# Create a histogram showing the distribution of total_bill.

# Think: Are you trying to compare categories or understand the distribution of one numerical variable?


sn.displot(data=c,x='total_bill')

# %%
# 4. KDE Plot

# Create a KDE plot for total_bill to understand its probability/distribution shape.

# Think: What does the smooth curve tell you that a histogram also tries to show?



sn.kdeplot(data=c,x ='total_bill' ,y = 'tip')

# %%
# 5. Bar Plot

# Create a bar plot showing the average tip amount for each day.

# Think: Which variable is categorical? Which numerical variable needs to be averaged?

sn.barplot(data=c,x='sex',y='total_bill')

# %%
#  Count Plot

# Create a count plot showing how many observations belong to each sex category.

# Think: Do you need a numerical y-axis, or does Seaborn calculate the count automatically?
sn.countplot(data=c,x ='sex')

# %%
#  Box Plot

# Create a box plot to compare the distribution of total_bill across different days.

# Think: Which variable should determine the groups?

sn.boxplot(data=c,x='time',y = 'tip')

# %%
#  Violin Plot

# Create a violin plot showing the distribution of tip for each time category.

# Think: What is the difference between a violin plot and a box plot?

sn.violinplot(data=c ,x ='time',y='tip')

# %%
# 9. Strip Plot

# Create a strip plot to display the individual total_bill observations for each day.

# Think: Why might a strip plot be useful when you want to see individual observations?



sn.stripplot(data=c,x='total_bill',y='day')

# %%
# 0. Swarm Plot

# Create a swarm plot showing individual tip values for each day, while trying to avoid overlapping points.

# Think: How is this different from a strip plot?
sn.swarmplot(data=c,x='day',y='tip')

# %%
# 1. Scatter Plot With Hue

# Create a scatter plot of total_bill vs tip, but visually separate the observations according to smoker.



sn.scatterplot(data=c,x='total_bill',y='tip',hue='smoker')

# %%
# 12. Change Point Size

# Create a scatter plot of total_bill vs tip and make the points larger or smaller using an appropriate parameter.

# Think: Which parameter controls marker size?

sn.scatterplot(data=c,x='total_bill',y='tip',size='size')

# %%
# 11. Scatter Plot With Hue

# Create a scatter plot of total_bill vs tip, but visually separate the observations according to smoker.

# Think: Which Seaborn parameter allows you to assign different colors to categories?
# //


sn.scatterplot(data=c,x='total_bill',y='tip',hue='smoker')

# %%
#  Joint Plot

# Create a joint plot using total_bill and tip.

# The plot should allow you to see:

# the relationship between the two variables
# the distribution of each variable

# Think: Which Seaborn function combines these views?



sn.jointplot(data=c,x='total_bill',y='tip')

# %%
# 5. Correlation Heatmap

# Calculate the correlations between numerical variables and display them as a heatmap.

# Make sure the correlation values are visible inside the cells.

# Think: What parameter is used to display annotations?

a=[[1,2,3],[2,5,6]]



sn.heatmap(a)

# %%
# 16. Regression Plot

# Create a regression plot showing the relationship between total_bill and tip.

# Think: What does the regression line help you understand?

sn.regplot(data=c,x='total_bill',y='tip')

# %%
# 7. Separate Regression Lines

# Create a regression visualization of total_bill vs tip, but create separate regression relationships for different smoker categories.

# Think: Is this better handled with an axes-level or figure-level Seaborn function?
