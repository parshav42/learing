# %% [markdown]
# <a href="https://colab.research.google.com/github/parshav42/learing/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

x = torch.arange(1,13)
x = x.reshape(3,4)

# %%
x

# %%
# Given:

# x = torch.tensor([
#     [1., 2., 3.],
#     [4., 5., 6.]
# ])

# Do these without using loops:

# Add 10 to every element.
# Multiply every element by 2.
# Calculate the mean of all elements.
# Find the maximum value

x = torch.range(1,12)

# %%
x = x.reshape(3,4)
x

# %%
# Add 10 to every element.
p = x +10
# Multiply every element by 2
m = x *2
#Calculate the mean of all elements
# x.mean()
#Find the maximum value
x.max()

# %%
x = torch.tensor([
    [1., 2., 3.],
    [4., 5., 6.]
])

# Write PyTorch code to get:

# 5
# The first row → [1, 2, 3]
# The second column → [2, 5]
# The last two elements → [5, 6]

# %%
x[1,1]

# %%
x[:1],x[:,1],x[1,1:]

# %%
p = torch.randn(4, 3, 2)
x.shape

# %%
x

# %%
b = torch.tensor([10,20,30])
y = x + b
y

# %%
A = torch.tensor([
    [1., 2.],
    [3., 4.]
])

B = torch.tensor([
    [5., 6.],
    [7., 8.]
])

# %%
x = A @ B
x

# %%
x = torch.rand(3,2)

# %%
x = torch.tensor([
    [1., 1.],
    [1., 2.],
    [4., 4.],
    [5., 4.]
])

y = torch.tensor([0., 0., 1., 1.])

# %%
from torch import nn

class mof(nn.Module):
    def __init__(self,imput):
        super().__init__()

        self.c = nn.Sequential(
            nn.Linear(imput , 3),
            nn.ReLU(),
            nn.Linear(3,2),
            nn.ReLU(),
            nn.Linear(2,1),
            nn.Sigmoid()
        )

    def forward(self, features):
        out = self.c(features)
        return out

# %%
loss_fu = nn.MSELoss()
optim = torch.optim.SGD(model.parameters(),lr=0.1)
# create model
model = mof(2)

# call model for forward pass
# model.forward(features)
model(x)

# %%
for epoches in range(100):

    y_pre = model(x)

    loss = loss_fu(y_pre,y)

    optim.zero_grad()

    loss.backward()

    optim.step()
    print(f'for epocs {epoches+1},loss {loss}')
