# %% [markdown]
# <a href="https://colab.research.google.com/github/parshav42/learing/blob/main/scikitlearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn import datasets

iris= datasets.load_iris()

# print(iris.data)
print(iris.target)

# %%
print(iris.data.shape)
print(iris.target.shape)

# %%
x = np.array([1,2,3,4])

print(x.shape)
