# %% [markdown]
# <a href="https://colab.research.google.com/github/parshav42/learing/blob/main/sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn as sk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print(sk.__version__)

# %%
X = np.array([[1,2],[3,4]])
y = np.array([[1,2]])

X , y

# %%
x = np.random.rand(40)
x1 = np.random.rand(40)

# %%
import random
s = []
for _ in range(40):
    s.append(random.randint(0, 1))

# %%
h = pd.DataFrame({'frame': x,'frame2': x1})
X = h[['frame','frame2']]
y = s

# %%
x_data = pd.DataFrame({'col1': x,'col2':x1,'output': y})

x_data.head(1)

# %%
x_data.head(4)

# %%
np.random.randint(0,2,20)
