# %% [markdown]
# <a href="https://colab.research.google.com/github/parshav42/learing/blob/main/sklearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn as sk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print(sk.__version__)

# %%
X = np.array([[1,2],[3,4]])
y = np.array([[1,2]])

X , y

# %%
df = pd.DataFrame({'frame': [1,2],'frame2':[4,5]})

X = df[['frame','frame2']]
y = pd.Series([0,1])




X, y
